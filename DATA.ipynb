# %% [markdown]
# copy code

# %%
from herbie import Herbie, FastHerbie
import pandas as pd, numpy as np
import xarray as xr
import dask

# %%
# 0z today
run = pd.Timestamp("2026-04-06-00", tz="utc").replace(tzinfo=None).floor('24h')

# %%
pd.Timestamp("2026-01-25-00")
# Out:
# Timestamp('2026-01-25 00:00:00')

# %%
H = Herbie(run, model="ifs", product="oper", fxx=6, save_dir='./data/', overwrite=True)
# Out:
# ✅ Found ┊ model=ifs ┊ product=oper ┊ 2026-Apr-06 00:00 UTC F06 ┊ GRIB2 @ google ┊ IDX @ google

# %%
table=H.inventory()

# %%
table.param.unique()
# Out:
# array(['asn', 'lsm', 'q', 'tcwv', 'rsn', 'sithick', 'sot', 'vsw', 'strd',
#        'ssr', 'str', 'ttr', 'w', '10fg', 'ewss', 'u', 'vo', 'r', 'v',
#        'gh', 'nsss', 'd', 't', 'ro', 'tp', 'sd', 'mx2t3', 'sf', 'mn2t3',
#        'msl', 'sve', 'mucape', 'svn', '100u', '100v', 'zos', 'skt', 'tcc',
#        '10u', 'ptype', '10v', 'tprate', '2t', '2d', 'ssrd', 'sp', 'tcw'],
#       dtype=object)

# %%
ss = ":tp:|:2t:|:2d:|sf:|wcf:|vis:"

# %%
H.inventory(ss)
# Out:
#      grib_message  start_byte  end_byte              range reference_time  \
# 37             38    25293503  25986430  25293503-25986430     2026-04-06
# 44             45    29869326  30215270  29869326-30215270     2026-04-06
# 94             95    72253150  72915205  72253150-72915205     2026-04-06
# 102           103    78139073  78826675  78139073-78826675     2026-04-06
#
#              valid_time            step param levelist levtype  number domain  \
# 37  2026-04-06 06:00:00 0 days 06:00:00    tp      NaN     sfc     NaN      g
# 44  2026-04-06 06:00:00 0 days 06:00:00    sf      NaN     sfc     NaN      g
# 94  2026-04-06 06:00:00 0 days 06:00:00    2t      NaN     sfc     NaN      g
# 102 2026-04-06 06:00:00 0 days 06:00:00    2d      NaN     sfc     NaN      g
#
#     expver class type stream                search_this
# 37    0001    od   fc   oper  :tp:sfc:g:0001:od:fc:oper
# 44    0001    od   fc   oper  :sf:sfc:g:0001:od:fc:oper
# ...

# %%
ss2 = "((gh|t|u|v):(1000|850|700|500|250))"
H.inventory(ss2)
# Out:
# /usr/local/anaconda3/envs/custom_envs/meteo473_sp26/lib/python3.13/site-packages/herbie/core.py:978: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   logic = df.search_this.str.contains(search)
#      grib_message  start_byte   end_byte                range reference_time  \
# 18             19    12350330   13057148    12350330-13057148     2026-04-06
# 22             23    15917479   16656848    15917479-16656848     2026-04-06
# 24             25    17059476   17558321    17059476-17558321     2026-04-06
# 30             31    21816898   22416622    21816898-22416622     2026-04-06
# 49             50    33354931   34087747    33354931-34087747     2026-04-06
# 52             53    35422145   36062316    35422145-36062316     2026-04-06
# 86             87    64758675   65508781    64758675-65508781     2026-04-06
# 90             91    68286056   69013064    68286056-69013064     2026-04-06
# ...

# %%
fp = H.download(ss)
fp
# Out:
# PosixPath('data/ifs/20260406/subset_26b20944__20260406000000-6h-oper-fc.grib2')

# %%
ds = xr.open_dataset(fp)
ds
# Out:
# Ignoring index file 'data/ifs/20260406/subset_26b20944__20260406000000-6h-oper-fc.grib2.5b7b6.idx' older than GRIB file
# <xarray.Dataset> Size: 17MB
# Dimensions:            (latitude: 721, longitude: 1440)
# Coordinates:
#   * latitude           (latitude) float64 6kB 90.0 89.75 89.5 ... -89.75 -90.0
#   * longitude          (longitude) float64 12kB -180.0 -179.8 ... 179.5 179.8
#     time               datetime64[ns] 8B ...
#     step               timedelta64[ns] 8B ...
#     surface            float64 8B ...
#     valid_time         datetime64[ns] 8B ...
#     heightAboveGround  float64 8B ...
# Data variables:
#     tp                 (latitude, longitude) float32 4MB ...
#     sf                 (latitude, longitude) float32 4MB ...
#     t2m                (latitude, longitude) float32 4MB ...
#     d2m                (latitude, longitude) float32 4MB ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             ecmf
# ...

# %%
filename = 'ecmwf_calm_006.nc'
ds.to_netcdf(filename)
# Out:
# sh: 1: getfattr: not found

# %%
H = FastHerbie([run], model="ifs", product="oper", fxx=np.arange(0,90,6).tolist(), save_dir='./data/', overwrite=True)

# %%
filepath = H.download(ss)
filepath
# Out:
# [PosixPath('data/ifs/20260406/subset_26efdb49__20260406000000-0h-oper-fc.grib2'),
#  PosixPath('data/ifs/20260406/subset_26b20944__20260406000000-6h-oper-fc.grib2'),
#  PosixPath('data/ifs/20260406/subset_26f10269__20260406000000-72h-oper-fc.grib2'),
#  PosixPath('data/ifs/20260406/subset_260eb94f__20260406000000-24h-oper-fc.grib2'),
#  PosixPath('data/ifs/20260406/subset_26059fc2__20260406000000-84h-oper-fc.grib2'),
#  PosixPath('data/ifs/20260406/subset_265ef177__20260406000000-78h-oper-fc.grib2'),
#  PosixPath('data/ifs/20260406/subset_2660db0e__20260406000000-30h-oper-fc.grib2'),
#  PosixPath('data/ifs/20260406/subset_26436d03__20260406000000-60h-oper-fc.grib2'),
#  PosixPath('data/ifs/20260406/subset_260e9787__20260406000000-36h-oper-fc.grib2'),
#  PosixPath('data/ifs/20260406/subset_2612d2a6__20260406000000-12h-oper-fc.grib2'),
#  PosixPath('data/ifs/20260406/subset_2678e5f3__20260406000000-54h-oper-fc.grib2'),
# ...

# %%
ds = xr.open_mfdataset(filepath, combine='nested', concat_dim='valid_time')
# Out:
# Ignoring index file '/courses/meteo473/sp26/473_sp26_group7/data/ifs/20260406/subset_26efdb49__20260406000000-0h-oper-fc.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/courses/meteo473/sp26/473_sp26_group7/data/ifs/20260406/subset_26b20944__20260406000000-6h-oper-fc.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/courses/meteo473/sp26/473_sp26_group7/data/ifs/20260406/subset_26f10269__20260406000000-72h-oper-fc.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/courses/meteo473/sp26/473_sp26_group7/data/ifs/20260406/subset_260eb94f__20260406000000-24h-oper-fc.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/courses/meteo473/sp26/473_sp26_group7/data/ifs/20260406/subset_26059fc2__20260406000000-84h-oper-fc.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/courses/meteo473/sp26/473_sp26_group7/data/ifs/20260406/subset_265ef177__20260406000000-78h-oper-fc.grib2.5b7b6.idx' older than GRIB file
# ...

# %%
ds
# Out:
# <xarray.Dataset> Size: 249MB
# Dimensions:            (valid_time: 15, latitude: 721, longitude: 1440)
# Coordinates:
#   * valid_time         (valid_time) datetime64[ns] 120B 2026-04-06 ... 2026-0...
#   * latitude           (latitude) float64 6kB 90.0 89.75 89.5 ... -89.75 -90.0
#   * longitude          (longitude) float64 12kB -180.0 -179.8 ... 179.5 179.8
#     time               datetime64[ns] 8B 2026-04-06
#     step               (valid_time) timedelta64[ns] 120B 0 days 00:00:00 ... ...
#     heightAboveGround  float64 8B 2.0
#     surface            float64 8B 0.0
# Data variables:
#     d2m                (valid_time, latitude, longitude) float32 62MB dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>
#     tp                 (valid_time, latitude, longitude) float32 62MB dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>
#     sf                 (valid_time, latitude, longitude) float32 62MB dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>
# ...

# %%
# May be necessary to ensure data is in the correct order
ds = ds.sortby('valid_time')
ds
# Out:
# <xarray.Dataset> Size: 249MB
# Dimensions:            (valid_time: 15, latitude: 721, longitude: 1440)
# Coordinates:
#   * valid_time         (valid_time) datetime64[ns] 120B 2026-04-06 ... 2026-0...
#   * latitude           (latitude) float64 6kB 90.0 89.75 89.5 ... -89.75 -90.0
#   * longitude          (longitude) float64 12kB -180.0 -179.8 ... 179.5 179.8
#     time               datetime64[ns] 8B 2026-04-06
#     step               (valid_time) timedelta64[ns] 120B 0 days 00:00:00 ... ...
#     heightAboveGround  float64 8B 2.0
#     surface            float64 8B 0.0
# Data variables:
#     d2m                (valid_time, latitude, longitude) float32 62MB dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>
#     tp                 (valid_time, latitude, longitude) float32 62MB dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>
#     sf                 (valid_time, latitude, longitude) float32 62MB dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>
# ...

# %%
# Always clip your data to area of interest before saving
ds1 = ds.sel(latitude=slice(42.3,39.7), longitude=slice(-80.6,-74.7))
ds1
# Out:
# <xarray.Dataset> Size: 64kB
# Dimensions:            (valid_time: 15, latitude: 11, longitude: 24)
# Coordinates:
#   * valid_time         (valid_time) datetime64[ns] 120B 2026-04-06 ... 2026-0...
#   * latitude           (latitude) float64 88B 42.25 42.0 41.75 ... 40.0 39.75
#   * longitude          (longitude) float64 192B -80.5 -80.25 ... -75.0 -74.75
#     time               datetime64[ns] 8B 2026-04-06
#     step               (valid_time) timedelta64[ns] 120B 0 days 00:00:00 ... ...
#     heightAboveGround  float64 8B 2.0
#     surface            float64 8B 0.0
# Data variables:
#     d2m                (valid_time, latitude, longitude) float32 16kB dask.array<chunksize=(1, 11, 24), meta=np.ndarray>
#     tp                 (valid_time, latitude, longitude) float32 16kB dask.array<chunksize=(1, 11, 24), meta=np.ndarray>
#     sf                 (valid_time, latitude, longitude) float32 16kB dask.array<chunksize=(1, 11, 24), meta=np.ndarray>
# ...

# %%
# Save as a netcdf file
# If the file already exists, delete it before tying again, otherwise you will see an error
fname = f'AprCalmVarecmwf_{run:%Y%m%d%h}.nc'
ds1.to_netcdf(fname)

# %%
ds_a = xr.open_dataset("CalmApril06ecmwf_20260406Apr.nc")
ds_a
# Out:
# sh: 1: getfattr: not found
# <xarray.Dataset> Size: 64kB
# Dimensions:            (valid_time: 15, latitude: 11, longitude: 24)
# Coordinates:
#   * valid_time         (valid_time) datetime64[ns] 120B 2026-04-06 ... 2026-0...
#   * latitude           (latitude) float64 88B 42.25 42.0 41.75 ... 40.0 39.75
#   * longitude          (longitude) float64 192B -80.5 -80.25 ... -75.0 -74.75
#     time               datetime64[ns] 8B ...
#     step               (valid_time) timedelta64[ns] 120B ...
#     heightAboveGround  float64 8B ...
#     surface            float64 8B ...
# Data variables:
#     d2m                (valid_time, latitude, longitude) float32 16kB ...
#     tp                 (valid_time, latitude, longitude) float32 16kB ...
#     sf                 (valid_time, latitude, longitude) float32 16kB ...
#     t2m                (valid_time, latitude, longitude) float32 16kB ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             ecmf
# ...

# %%
ds_b = xr.open_dataset("ecmwf_20260323Mar.nc")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[153], line 1
# ----> 1 ds_b = xr.open_dataset("ecmwf_20260323Mar.nc")
#
# File /usr/local/anaconda3/envs/custom_envs/meteo473_sp26/lib/python3.13/site-packages/xarray/backends/api.py:587, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, create_default_indexes, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     584     kwargs.update(backend_kwargs)
#     586 if engine is None:
# --> 587     engine = plugins.guess_engine(filename_or_obj)
#     589 if from_array_kwargs is None:
#     590     from_array_kwargs = {}
#
# ...

# %%
ds_merge = xr.merge([ds_a, ds_b], compat = 'override')
ds_merge.to_netcdf(

# %%
ds_merge.t2m.isel(valid_time = 1).plot()

# %% [markdown]
# # M2 Part 4

# %%
#calm day
run2 = pd.Timestamp("2026-04-06-00", tz="utc").replace(tzinfo=None).floor('24h')

# %%
H2 = Herbie(run2, model="ifs", product="oper", fxx=6, save_dir='./data/', overwrite=True)
# Out:
# ✅ Found ┊ model=ifs ┊ product=oper ┊ 2026-Apr-06 00:00 UTC F06 ┊ GRIB2 @ google ┊ IDX @ google

# %%
table2=H2.inventory()

# %%
sscalm = "10fg"

# %%
H2.inventory(sscalm)
# Out:
#     grib_message  start_byte  end_byte              range reference_time  \
# 16            17    10533589  11953800  10533589-11953800     2026-04-06
#
#             valid_time            step param levelist levtype  number domain  \
# 16 2026-04-06 06:00:00 0 days 06:00:00  10fg      NaN     sfc     NaN      g
#
#    expver class type stream                  search_this
# 16   0001    od   fc   oper  :10fg:sfc:g:0001:od:fc:oper

# %%
fp2 = H2.download(sscalm)
fp2
# Out:
# [PosixPath('data/ifs/20260323/subset_aaef3760__20260323000000-0h-oper-fc.grib2'),
#  PosixPath('data/ifs/20260323/subset_aab283c9__20260323000000-6h-oper-fc.grib2'),
#  PosixPath('data/ifs/20260323/subset_aa6083c9__20260323000000-30h-oper-fc.grib2'),
#  PosixPath('data/ifs/20260323/subset_aa7858ca__20260323000000-54h-oper-fc.grib2'),
#  PosixPath('data/ifs/20260323/subset_aaf13506__20260323000000-72h-oper-fc.grib2'),
#  PosixPath('data/ifs/20260323/subset_aa4324ee__20260323000000-60h-oper-fc.grib2'),
#  PosixPath('data/ifs/20260323/subset_aa123506__20260323000000-12h-oper-fc.grib2'),
#  PosixPath('data/ifs/20260323/subset_aa1c3506__20260323000000-48h-oper-fc.grib2'),
#  PosixPath('data/ifs/20260323/subset_aae758ca__20260323000000-42h-oper-fc.grib2'),
#  PosixPath('data/ifs/20260323/subset_aa0e24ee__20260323000000-36h-oper-fc.grib2'),
#  PosixPath('data/ifs/20260323/subset_aa0558ca__20260323000000-84h-oper-fc.grib2'),
# ...

# %%
dscalm = xr.open_dataset(fp2)
dscalm
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 dscalm = xr.open_dataset(fp2)
#       2 dscalm
#
# File /usr/local/anaconda3/envs/custom_envs/meteo473_sp26/lib/python3.13/site-packages/xarray/backends/api.py:587, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, create_default_indexes, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     584     kwargs.update(backend_kwargs)
#     586 if engine is None:
# --> 587     engine = plugins.guess_engine(filename_or_obj)
#     589 if from_array_kwargs is None:
#     590     from_array_kwargs = {}
#
# ...

# %%
filenamecalm = 'ecmwf_calm10fg.nc'
dscalm.to_netcdf(filenamecalm)

# %%
H2 = FastHerbie([run], model="ifs", product="oper", fxx=np.arange(0,90,6).tolist(), save_dir='./data/', overwrite=True)

# %%
filepath2 = H2.download(sscalm)
filepath2
# Out:
# [PosixPath('data/ifs/20260323/subset_aa1c3506__20260323000000-48h-oper-fc.grib2'),
#  PosixPath('data/ifs/20260323/subset_aaef3760__20260323000000-0h-oper-fc.grib2'),
#  PosixPath('data/ifs/20260323/subset_aa0558ca__20260323000000-84h-oper-fc.grib2'),
#  PosixPath('data/ifs/20260323/subset_aab283c9__20260323000000-6h-oper-fc.grib2'),
#  PosixPath('data/ifs/20260323/subset_aa7858ca__20260323000000-54h-oper-fc.grib2'),
#  PosixPath('data/ifs/20260323/subset_aa6083c9__20260323000000-30h-oper-fc.grib2'),
#  PosixPath('data/ifs/20260323/subset_aa0e8a0a__20260323000000-24h-oper-fc.grib2'),
#  PosixPath('data/ifs/20260323/subset_aae758ca__20260323000000-42h-oper-fc.grib2'),
#  PosixPath('data/ifs/20260323/subset_aa4324ee__20260323000000-60h-oper-fc.grib2'),
#  PosixPath('data/ifs/20260323/subset_aaf13506__20260323000000-72h-oper-fc.grib2'),
#  PosixPath('data/ifs/20260323/subset_aa123506__20260323000000-12h-oper-fc.grib2'),
# ...

# %%
dscalm = xr.open_mfdataset(filepath2, combine='nested', concat_dim='valid_time')
# Out:
# Ignoring index file '/courses/meteo473/sp26/473_sp26_group7/data/ifs/20260323/subset_aa1c3506__20260323000000-48h-oper-fc.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/courses/meteo473/sp26/473_sp26_group7/data/ifs/20260323/subset_aaef3760__20260323000000-0h-oper-fc.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/courses/meteo473/sp26/473_sp26_group7/data/ifs/20260323/subset_aa0558ca__20260323000000-84h-oper-fc.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/courses/meteo473/sp26/473_sp26_group7/data/ifs/20260323/subset_aab283c9__20260323000000-6h-oper-fc.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/courses/meteo473/sp26/473_sp26_group7/data/ifs/20260323/subset_aa7858ca__20260323000000-54h-oper-fc.grib2.5b7b6.idx' older than GRIB file
# Ignoring index file '/courses/meteo473/sp26/473_sp26_group7/data/ifs/20260323/subset_aa6083c9__20260323000000-30h-oper-fc.grib2.5b7b6.idx' older than GRIB file
# ...

# %%
# May be necessary to ensure data is in the correct order
dscalm = dscalm.sortby('valid_time')
dscalm
# Out:
# <xarray.Dataset> Size: 62MB
# Dimensions:            (valid_time: 15, latitude: 721, longitude: 1440)
# Coordinates:
#   * valid_time         (valid_time) datetime64[ns] 120B 2026-03-23 ... 2026-0...
#   * latitude           (latitude) float64 6kB 90.0 89.75 89.5 ... -89.75 -90.0
#   * longitude          (longitude) float64 12kB -180.0 -179.8 ... 179.5 179.8
#     time               datetime64[ns] 8B 2026-03-23
#     step               (valid_time) timedelta64[ns] 120B 0 days 00:00:00 ... ...
#     heightAboveGround  float64 8B 10.0
# Data variables:
#     fg10               (valid_time, latitude, longitude) float32 62MB dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
# ...

# %%
# Always clip your data to area of interest before saving
dscalm2 = dscalm.sel(latitude=slice(42.3,39.7), longitude=slice(-80.6,-74.7))
dscalm2
# Out:
# <xarray.Dataset> Size: 16kB
# Dimensions:            (valid_time: 15, latitude: 11, longitude: 24)
# Coordinates:
#   * valid_time         (valid_time) datetime64[ns] 120B 2026-03-23 ... 2026-0...
#   * latitude           (latitude) float64 88B 42.25 42.0 41.75 ... 40.0 39.75
#   * longitude          (longitude) float64 192B -80.5 -80.25 ... -75.0 -74.75
#     time               datetime64[ns] 8B 2026-03-23
#     step               (valid_time) timedelta64[ns] 120B 0 days 00:00:00 ... ...
#     heightAboveGround  float64 8B 10.0
# Data variables:
#     fg10               (valid_time, latitude, longitude) float32 16kB dask.array<chunksize=(1, 11, 24), meta=np.ndarray>
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
# ...

# %%
# Save as a netcdf file
# If the file already exists, delete it before tying again, otherwise you will see an error
fname2 = f'ecmwf_{run2:%Y%m%d%h}10fg.nc'
dscalm2.to_netcdf(fname2)

# %%
ds_calm = xr.open_dataset("ecmwf_20260406Apr.nc")
# Out:
# sh: 1: getfattr: not found

# %%
ds_a = xr.open_dataset("ecmwf_20260406Apr.nc")
ds_b = xr.open_dataset("ecmwf_20260406Apr10fg.nc")
ds2 = xr.merge([ds_a, ds_b], compat = 'override')
ds2
# Out:
# sh: 1: getfattr: not found
# sh: 1: getfattr: not found
# <xarray.Dataset> Size: 80kB
# Dimensions:            (valid_time: 15, latitude: 11, longitude: 24)
# Coordinates:
#   * valid_time         (valid_time) datetime64[ns] 120B 2026-03-23 ... 2026-0...
#   * latitude           (latitude) float64 88B 42.25 42.0 41.75 ... 40.0 39.75
#   * longitude          (longitude) float64 192B -80.5 -80.25 ... -75.0 -74.75
#     time               datetime64[ns] 8B ...
#     step               (valid_time) timedelta64[ns] 120B ...
#     heightAboveGround  float64 8B ...
#     surface            float64 8B ...
# Data variables:
#     d2m                (valid_time, latitude, longitude) float32 16kB ...
#     tp                 (valid_time, latitude, longitude) float32 16kB ...
#     sf                 (valid_time, latitude, longitude) float32 16kB ...
#     t2m                (valid_time, latitude, longitude) float32 16kB ...
# ...
