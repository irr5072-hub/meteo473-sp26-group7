# %%
# Importing cartopy
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.Mercator())

ax.add_feature(cfeature.COASTLINE.with_scale('50m'))
ax.add_feature(cfeature.BORDERS.with_scale('50m'), linewidth=2)
ax.add_feature(cfeature.STATES.with_scale('50m'), linestyle='--', edgecolor='black')

data_projection = ccrs.PlateCarree()
ax.plot(-77.86, 40.81, marker='o', color='tab:red', transform=data_projection)

ax.set_extent([-80.6, -74.5, 39.5, 42.5])

# %%
from metpy.plots import USCOUNTIES

# %%
proj = ccrs.LambertConformal(central_longitude=-85.0, central_latitude=45.0)

fig = plt.figure(figsize=(12, 9))
ax1 = fig.add_subplot(1, 3, 1, projection=proj)
ax2 = fig.add_subplot(1, 3, 2, projection=proj)
ax3 = fig.add_subplot(1, 3, 3, projection=proj)

for scale, axis in zip(['20m', '5m', '500k'], [ax1, ax2, ax3]):
    axis.set_extent([270.25, 270.9, 38.15, 38.75], ccrs.Geodetic())
    axis.add_feature(USCOUNTIES.with_scale(scale), edgecolor='black')
# Out:
# Downloading file 'us_counties_20m.cpg' from 'https://github.com/Unidata/MetPy/raw/v1.7.1/staticdata/us_counties_20m.cpg' to '/home/mpf5617/.cache/metpy/v1.7.1'.
# Downloading file 'us_counties_20m.dbf' from 'https://github.com/Unidata/MetPy/raw/v1.7.1/staticdata/us_counties_20m.dbf' to '/home/mpf5617/.cache/metpy/v1.7.1'.
# Downloading file 'us_counties_20m.prj' from 'https://github.com/Unidata/MetPy/raw/v1.7.1/staticdata/us_counties_20m.prj' to '/home/mpf5617/.cache/metpy/v1.7.1'.
# Downloading file 'us_counties_20m.shx' from 'https://github.com/Unidata/MetPy/raw/v1.7.1/staticdata/us_counties_20m.shx' to '/home/mpf5617/.cache/metpy/v1.7.1'.
# Downloading file 'us_counties_20m.shp' from 'https://github.com/Unidata/MetPy/raw/v1.7.1/staticdata/us_counties_20m.shp' to '/home/mpf5617/.cache/metpy/v1.7.1'.
# Downloading file 'us_counties_5m.cpg' from 'https://github.com/Unidata/MetPy/raw/v1.7.1/staticdata/us_counties_5m.cpg' to '/home/mpf5617/.cache/metpy/v1.7.1'.
# Downloading file 'us_counties_5m.dbf' from 'https://github.com/Unidata/MetPy/raw/v1.7.1/staticdata/us_counties_5m.dbf' to '/home/mpf5617/.cache/metpy/v1.7.1'.
# Downloading file 'us_counties_5m.prj' from 'https://github.com/Unidata/MetPy/raw/v1.7.1/staticdata/us_counties_5m.prj' to '/home/mpf5617/.cache/metpy/v1.7.1'.
# Downloading file 'us_counties_5m.shx' from 'https://github.com/Unidata/MetPy/raw/v1.7.1/staticdata/us_counties_5m.shx' to '/home/mpf5617/.cache/metpy/v1.7.1'.
# Downloading file 'us_counties_5m.shp' from 'https://github.com/Unidata/MetPy/raw/v1.7.1/staticdata/us_counties_5m.shp' to '/home/mpf5617/.cache/metpy/v1.7.1'.
# Downloading file 'us_counties_500k.cpg' from 'https://github.com/Unidata/MetPy/raw/v1.7.1/staticdata/us_counties_500k.cpg' to '/home/mpf5617/.cache/metpy/v1.7.1'.
# Downloading file 'us_counties_500k.dbf' from 'https://github.com/Unidata/MetPy/raw/v1.7.1/staticdata/us_counties_500k.dbf' to '/home/mpf5617/.cache/metpy/v1.7.1'.
# Downloading file 'us_counties_500k.prj' from 'https://github.com/Unidata/MetPy/raw/v1.7.1/staticdata/us_counties_500k.prj' to '/home/mpf5617/.cache/metpy/v1.7.1'.
# Downloading file 'us_counties_500k.shx' from 'https://github.com/Unidata/MetPy/raw/v1.7.1/staticdata/us_counties_500k.shx' to '/home/mpf5617/.cache/metpy/v1.7.1'.
# Downloading file 'us_counties_500k.shp' from 'https://github.com/Unidata/MetPy/raw/v1.7.1/staticdata/us_counties_500k.shp' to '/home/mpf5617/.cache/metpy/v1.7.1'.
